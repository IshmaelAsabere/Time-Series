# %% [markdown]
# # Arima Model in Python

# %% [markdown]
# # <font color="red"> 1 ARMA Models <font>

# %%
### 1.1 Intro to time series and stationarity

# %%
### 1.2 Making time series stationary

# %%
### 1.3 Intro to AR, MA and ARMA models

# %% [markdown]
# # <font color="red"> 2 Fitting the Future <font>

# %%
### 2.1 Fitting time series models

# %%
### 2.2 Forecasting

# %%
### 2.3 Intro to ARIMA models

# %% [markdown]
# # <font color="red"> 3 The Best of the Best Models <font>

# %%
### 3.1 Intro to ACF and PACF

# %%
### 3.2 Intro to AIC and BIC

# %%
### 3.3 Model diagnostics

# %%
### 3.4 Box-Jenkins method

# %% [markdown]
# # <font color="red"> 4 Seasonal ARIMA Models <font>

# %%
### 4.1 Seasonal time series

# %%
### 4.2 SARIMA models

# %%
### 4.3 Automation and saving

# %%
### 4.4 SARIMA and Box-Jenkins
