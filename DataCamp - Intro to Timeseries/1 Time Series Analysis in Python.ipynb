# %% [markdown]
# # <font color="red"> 1 Correlation and Autocorrelation <font>

# %%
### 1.1 Introduction to Course

# %%
### 1.2 Correlation of Two Time Series

# %%
### 1.3 Simple Linear Regression

# %%
### 1.4 Autocorrelation

# %% [markdown]
# # <font color="red"> 2 Some Simple Time Series <font>

# %%
### 2.1 Autocorrelation Function

# %%
### 2.2 White Noise

# %%
### 2.3 Random Walk

# %%
### 2.4 Stationarity

# %% [markdown]
# # <font color="red"> 3 Autoregressive (AR) Models <font>

# %%
### 3.1 Describe AR Model

# %%
### 3.2 Estimating and Forecasting AR Model

# %%
### 3.3 Choosing the Right Model

# %% [markdown]
# # <font color="red"> 4 Moving Average (MA) and ARMA Models <font>

# %%
### 4.1 Describe Model

# %%
### 4.2 Estimation and Forecasting an MA Model

# %%
### 4.3 ARMA models

# %% [markdown]
# # <font color="red"> 5 Putting It All Together <font>

# %%
### 5.1 Cointegration Models

# %%
### 5.2 Case Study: Climate Change
