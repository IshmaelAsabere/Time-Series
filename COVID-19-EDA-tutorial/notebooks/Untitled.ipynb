# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

# Data urls
url = 'https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/1_OneNum.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    price
# 0   75.0
# 1  104.0
# 2  369.0
# 3  300.0
# 4   92.0

# %%
data %>%
  filter( price<300 ) %>%
  ggplot( 
      aes(x=price)) +
    stat_bin(breaks=seq(0,300,10), fill="#69b3a2", color="#e9ecef", alpha=0.9) +
    ggtitle("Night price distribution of Airbnb appartements") +
    theme_ipsum() +
    theme(
      plot.title = element_text(size=12)
    )

# %%
(ggplot(mpg)         # defining what data to use
 + aes(x='class')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)

# %%
(ggplot((data) 
        + aes(x='price') 
        + geom_bar()  
    ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py in __radd__(self, gg)
#     203         try:
# --> 204             gg.layers.append(self)
#     205         except AttributeError:
#
# AttributeError: 'float' object has no attribute 'layers'
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\geoms\geom.py in __radd__(self, gg, inplace)
#     353         gg = gg if inplace else deepcopy(gg)
# --> 354         gg += self.to_layer()  # Add layer
#     355         return gg
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py in __radd__(self, gg)
#     206             msg = "Cannot add layer to object of type {!r}".format
# --> 207             raise PlotnineError(msg(type(gg)))
#     208         return gg
#
# PlotnineError: "Cannot add layer to object of type <class 'float'>"
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-12-7795815dabf3> in <module>
#       1 (ggplot((data)
#       2         + aes(x='price')
# ----> 3         + geom_bar()
#       4     ))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     775                 self = self.fillna(fill_value)
#     776
# --> 777             new_data = dispatch_to_series(self, other, op, str_rep)
#     778             return self._construct_result(new_data)
#     779
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     379         # Get the appropriate array-op to apply to each block's values.
#     380         array_op = get_array_op(func, str_rep=str_rep)
# --> 381         bm = left._data.apply(array_op, right=right)
#     382         return type(left)(bm)
#     383
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     147
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#     151         result = masked_arith_op(left, right, op)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#     123     return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\geoms\geom.py in __radd__(self, gg, inplace)
#     351             ggplot object with added layer.
#     352         """
# --> 353         gg = gg if inplace else deepcopy(gg)
#     354         gg += self.to_layer()  # Add layer
#     355         return gg
#
# ~\AppData\Local\Continuum\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     139         memo = {}
#     140
# --> 141     d = id(x)
#     142     y = memo.get(d, _nil)
#     143     if y is not _nil:
#
# SystemError: <built-in function id> returned a result with an error set
